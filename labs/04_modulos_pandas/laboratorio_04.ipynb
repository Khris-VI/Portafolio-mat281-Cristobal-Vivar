# %% [markdown]
# <img src="images/usm.jpg" width="480" height="240" align="left"/>

# %% [markdown]
# # MAT281 - Laboratorio N°04
#
# ## Objetivos de la clase
#
# * Reforzar los conceptos básicos de los módulos de pandas.

# %% [markdown]
# ## Contenidos
#
# * [Problema 01](#p1)
# * [Problema 02](#p2)

# %% [markdown]
# ## Problema 01
#
#
# <img src="https://image.freepik.com/vector-gratis/varios-automoviles-dibujos-animados_23-2147613095.jpg" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `Automobile_data.csv`, el cual contiene información tal como: compañia, precio, kilometraje, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import numpy as np
import os

# %%
# cargar datos
df = pd.read_csv(os.path.join("data","Automobile_data.csv")).set_index('index')
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:

# %% [markdown]
# 1. Elimine los valores nulos (Nan)

# %%
#Se eliminan los valores usando dropna y se redefine el DataFrame ahora si  los valorees nulos
df=df.dropna()

# %% [markdown]
# 2. Encuentra el nombre de la compañía de automóviles más cara

# %%
grupo= df.groupby('company')  #Se agrupan los datos respecto a la columna company
grupo_mean = grupo.agg({'price':[np.mean]}).reset_index() #Se saca el promedio de precios de cada compañia
grupo_mean.max().to_frame() #se devuelve el maximo precio de junto con su compañia
# Out:
#                   0
# company       volvo
# price   mean  35528

# %% [markdown]
# 3. Imprimir todos los detalles de Toyota Cars

# %%
toy= df[df.company == 'toyota'] #Se crea un dataframe solo con la compañia de interés
toy
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66             62               35   5348.0
# 67             62               31   6338.0
# 68             62               31   6488.0
# 69             62               31   6918.0
# 70             62               27   7898.0
# 71             62               27   8778.0
# 79            156               19  15750.0

# %%
toy.describe() #Se describen estadisticas de la compañía Toyota
# Out:
#        wheel-base      length  horsepower  average-mileage         price
# count    7.000000    7.000000    7.000000         7.000000      7.000000
# mean    96.957143  167.571429   75.428571        28.714286   8216.857143
# std      3.326087   10.479299   35.528660         5.089672   3502.409048
# min     95.700000  158.700000   62.000000        19.000000   5348.000000
# 25%     95.700000  158.700000   62.000000        27.000000   6413.000000
# 50%     95.700000  169.700000   62.000000        31.000000   6918.000000
# 75%     95.700000  169.700000   62.000000        31.000000   8338.000000
# max    104.500000  187.800000  156.000000        35.000000  15750.000000

# %% [markdown]
# 4. Cuente el total de automóviles por compañía

# %%
comp= df.groupby('company') #Se agrupan los datos respecto a la columna company
comp[['company']].count()  # Se cuenta cuantos elementos hay en cada compañia de la agrupación
# Out:
#                company
# company
# alfa-romero          3
# audi                 4
# bmw                  6
# chevrolet            3
# dodge                2
# honda                3
# isuzu                1
# jaguar               3
# mazda                5
# mercedes-benz        4
# mitsubishi           4
# nissan               5
# porsche              2
# toyota               7
# volkswagen           4
# volvo                2

# %% [markdown]
# 5. Encuentra el coche con el precio más alto por compañía

# %%
#Se agrupan los datos con respecto a la columna company
comp= df.groupby(['company'])

#Se crea el DataFame pmax transformando todos los precios de df a los precios maximos de cada compañía agrupada
pmax= comp['price'].transform(max) 

#Se define una máscara que cheque si el atributo precio de cada fila de pmax es igual al de cada fila de df
mask = (pmax == df['price'])

#Se presentan las filas correspondientes a los autos de precio maximo de cada compañía
df[mask].reset_index()
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       1    alfa-romero  convertible        88.6   168.8        dohc
# 1       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 2       6           audi        wagon       105.8   192.7         ohc
# 3      14            bmw        sedan       103.5   193.8         ohc
# 4      18      chevrolet        sedan        94.5   158.8         ohc
# 5      19          dodge    hatchback        93.7   157.3         ohc
# 6      28          honda        sedan        96.5   175.4         ohc
# 7      30          isuzu        sedan        94.3   170.7         ohc
# 8      35         jaguar        sedan       102.0   191.7        ohcv
# 9      43          mazda        sedan       104.9   175.0         ohc
# 10     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     52     mitsubishi        sedan        96.3   172.4         ohc
# ...

# %% [markdown]
# 6. Encuentre el kilometraje promedio (**average-mileage**) de cada compañía automotriz

# %%
comp= df.groupby('company') #Se agrupan los datos con respecto a la columna company
comp_mean = grupo.agg({'average-mileage':[np.mean]}).reset_index() #Se saca el promedio de average-mileage de cada compañia
comp_mean
# Out:
#           company average-mileage
#                              mean
# 0     alfa-romero       20.333333
# 1            audi       20.000000
# 2             bmw       19.000000
# 3       chevrolet       41.000000
# 4           dodge       31.000000
# 5           honda       26.333333
# 6           isuzu       24.000000
# 7          jaguar       14.333333
# 8           mazda       28.000000
# 9   mercedes-benz       18.000000
# 10     mitsubishi       29.500000
# 11         nissan       31.400000
# 12        porsche       17.000000
# 13         toyota       28.714286
# 14     volkswagen       31.750000
# 15          volvo       23.000000

# %% [markdown]
# 7. Ordenar todos los autos por columna de precio (**price**)

# %%
#Se ordenan los datos de mayor a menor usando a función Sort_Values
df_ordenada = df.sort_values(['price'],ascending=False).reset_index() 
df_ordenada.head() #Si se desea ver la tabla completa, borrar esta linea
# Out:
#    index        company   body-style  wheel-base  length engine-type  \
# 0     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 1     14            bmw        sedan       103.5   193.8         ohc
# 2     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 3     62        porsche  convertible        89.5   168.9        ohcf
# 4     15            bmw        sedan       110.0   197.0         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0            eight         184               14  45400.0
# 1              six         182               16  41315.0
# 2            eight         184               14  40960.0
# 3              six         207               17  37028.0
# 4              six         182               15  36880.0

# %% [markdown]
# ## Problema 02
#
#
# Siguiendo la temática de los automóviles, resuelva los siguientes problemas:
#
# #### a) Subproblema 01
# A partir de los siguientes diccionarios:

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'],
              'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 
                'Price': [29995, 23600, 61500 , 58900]}

# %% [markdown]
# * Cree dos dataframes (**carsDf1** y **carsDf2**) según corresponda.
# * Concatene ambos dataframes (**carsDf**) y añada una llave ["Germany", "Japan"], según corresponda.

# %%
#Creación del DataFrame carsDf1
carsDf1 = pd.DataFrame(GermanCars)
carsDf1
# Out:
#     Company   Price
# 0      Ford   23845
# 1  Mercedes  171995
# 2       BMV  135925
# 3      Audi   71400

# %%
#Creación del DataFrame carsDf2
carsDf2 = pd.DataFrame(japaneseCars)
carsDf2
# Out:
#        Company  Price
# 0       Toyota  29995
# 1        Honda  23600
# 2       Nissan  61500
# 3  Mitsubishi   58900

# %%
llave=['GermanCars', 'japaneseCars'] #Definicion del cjto de llaves solicitado
frames = [carsDf1, carsDf2] #Definición de los DataFrames a concatenar

carsDf = pd.concat(       #Concatenación horizontal (axis 1)
    frames,
    keys=llave,
    axis = 1
) 
carsDf
# Out:
#   GermanCars         japaneseCars
#      Company   Price      Company  Price
# 0       Ford   23845       Toyota  29995
# 1   Mercedes  171995        Honda  23600
# 2        BMV  135925       Nissan  61500
# 3       Audi   71400  Mitsubishi   58900

# %% [markdown]
# #### b) Subproblema 02
#
# A partir de los siguientes diccionarios:

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# %% [markdown]
# * Cree dos dataframes (**carsDf1** y **carsDf2**) según corresponda.
# *  Junte ambos dataframes (**carsDf**) por la llave **Company**.

# %%
#Creación del DataFrame carsDf1
carsDf1 = pd.DataFrame(Car_Price)
carsDf1
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
#Creación del DataFrame carsDf2
carsDf2 = pd.DataFrame(car_Horsepower)
carsDf2
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %%
#Fusión de los dataframes con la llave solicitada
carsDf = pd.merge(
    carsDf1,
    carsDf2,
    on='Company'
)
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
